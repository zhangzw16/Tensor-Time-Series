# %%
from data_analysis import DataAnalysis
import matplotlib.pyplot as plt
root_path = '/home/ysc/workspace/Tensor-Time-Series/datasets/Tensor-Time-Series-Dataset/Processed_Data/'
# pkl_path = root_path + "JONAS_NYC_bike/JONAS_NYC_bike.pkl"
pkl_path = root_path + 'JONAS_NYC_taxi/JONAS_NYC_taxi.pkl'
# pkl_path = root_path + 'PEMS04/PEMS04.pkl'
# pkl_path = '/home/ysc/workspace/Tensor-Time-Series/datasets/Tensor-Time-Series-Dataset/Processed_Data/Metr-LA/Metr-LA.pkl'
data_analysis = DataAnalysis(pkl_path)
sim_eval_1 = data_analysis.eval_tensor(axis = 1,method = 'corelation')
sim_eval_2 = data_analysis.eval_tensor(axis = 2,method = 'corelation')

plt.figure()
plt.subplot(121)
plt.imshow(sim_eval_1, cmap='hot', interpolation='nearest')
plt.title('Similarity Evaluation by axis 1')
plt.colorbar()
plt.subplot(122)
plt.imshow(sim_eval_2, cmap='hot', interpolation='nearest')
plt.title('Similarity Evaluation by axis 2')
plt.colorbar()
plt.show()

periods = data_analysis.find_periods(k = 5)
for period in periods:
    print(period)

periods = data_analysis.find_periods_byacf(k = 5)
for period in periods:
    print(period)

pe = data_analysis.tensor_permutation_entropy(embedding = 5, time_delay = 12)
print(f"permutation entropy {pe}")
# Out:
# /home/ysc/workspace/Tensor-Time-Series/tasks/data_analysis.py:68: RuntimeWarning: divide by zero encountered in true_divide
#   periods = 1 / frequencies[indices]
# {'period': array([47.]), 'ratio_across_variants': 0.39453125, 'varience': 6.594217010339231e+35, 'energy_density': 0.0008340675431727758}
# {'period': array([48.]), 'ratio_across_variants': 0.39453125, 'varience': 4111.438461303711, 'energy_density': 0.0008340675431727758}
# {'period': array([23.]), 'ratio_across_variants': 0.36328125, 'varience': 38434.068588256836, 'energy_density': 0.0008193624877108038}
# {'period': array([24.]), 'ratio_across_variants': 0.36328125, 'varience': 100981.46966552734, 'energy_density': 0.0008193624877108038}
# {'period': array([25.]), 'ratio_across_variants': 0.359375, 'varience': 3.3100892473159526e+35, 'energy_density': 0.0007843782976847702}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [1], in <cell line: 27>()
#      24 for period in periods:
#      25     print(period)
# ---> 27 periods = data_analysis.find_periods_byacf(k = 5)
#      28 for period in periods:
#      29     print(period)
#
# File ~/workspace/Tensor-Time-Series/tasks/data_analysis.py:173, in DataAnalysis.find_periods_byacf(self, k)
#     171 top_k_periods = []
#     172 for i in range(k):
# --> 173     period = periods[:,i].flatten()
#     174     # mean = np.mean(period)
#     175     # sigma = np.std(period)
#     176     # outliers = np.where(abs(period - mean)> 2*sigma)
#     177     # np.delete(period, outliers)
#     178     mode = stats.mode(period)[0]
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
