# %%
from data_analysis import DataAnalysis
import matplotlib.pyplot as plt

# pkl_path = "/home/ysc/workspace/Tensor-Time-Series/datasets/Tensor-Time-Series-Dataset/Processed_Data/JONAS_NYC_bike/JONAS_NYC_bike.pkl"
pkl_path = '/home/ysc/workspace/Tensor-Time-Series/datasets/Tensor-Time-Series-Dataset/Processed_Data/Metr-LA/Metr-LA.pkl'
data_analysis = DataAnalysis(pkl_path)
sim_evals = data_analysis.eval_tensor(axis = 1,method = 'corelation')
plt.imshow(sim_evals, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()
periods = data_analysis.find_periods(k = 10)
print(periods)
# Out:
# /home/ysc/workspace/Tensor-Time-Series/tasks/data_analysis.py:64: RuntimeWarning: divide by zero encountered in true_divide
#   periods = 1 / frequencies[indices]
# [{'period': array([290.]), 'ratio_across_variants': 0.2318840579710145, 'varience': 2.3943413761502717e+36, 'amplitude': 0.0009013891149985734}, {'period': array([285.]), 'ratio_across_variants': 0.2318840579710145, 'varience': 9716726.906718945, 'amplitude': 0.0009013891149985734}, {'period': array([5712.]), 'ratio_across_variants': 0.18357487922705315, 'varience': 2.779500768333649e+36, 'amplitude': 0.0007434208075333233}, {'period': array([4284.]), 'ratio_across_variants': 0.18840579710144928, 'varience': 38851768.74274779, 'amplitude': 0.0007380251551674354}, {'period': array([5712.]), 'ratio_across_variants': 0.14009661835748793, 'varience': 3.160689445133694e+36, 'amplitude': 0.0005316571957907917}, {'period': array([4284.]), 'ratio_across_variants': 0.14492753623188406, 'varience': 23287436.3796588, 'amplitude': 0.00063464247069453}, {'period': array([1803.]), 'ratio_across_variants': 0.12077294685990338, 'varience': 1.2150389073001378e+36, 'amplitude': 0.0005915962230134047}, {'period': array([1632.]), 'ratio_across_variants': 0.13043478260869565, 'varience': 30015918.4226003, 'amplitude': 0.0006246857271360223}, {'period': array([1803.]), 'ratio_across_variants': 0.14009661835748793, 'varience': 8.139966535834256e+35, 'amplitude': 0.0005487106572922435}, {'period': array([1632.]), 'ratio_across_variants': 0.15458937198067632, 'varience': 37851023.58262736, 'amplitude': 0.0007826993951137142}]
